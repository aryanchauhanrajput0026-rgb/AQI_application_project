# %%
import pandas as pd
import joblib
import datetime
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error , mean_squared_error

# %%
df = pd.read_csv("cleaned_city_day_aqi.csv")
df
# Out:
#                 City        Date   PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-29   83.13  96.18   6.93  28.71  33.72  16.31
# 1          Ahmedabad  2015-01-30   79.84  96.18  13.85  28.68  41.08  16.31
# 2          Ahmedabad  2015-01-31   94.52  96.18  24.39  32.66  52.61  16.31
# 3          Ahmedabad  2015-02-01  135.99  96.18  43.48  42.08  84.57  16.31
# 4          Ahmedabad  2015-02-02  178.33  96.18  54.56  35.31  72.80  16.31
# ...              ...         ...     ...    ...    ...    ...    ...    ...
# 24845  Visakhapatnam  2020-06-27   15.02  50.94   7.68  25.06  19.54  12.47
# 24846  Visakhapatnam  2020-06-28   24.38  74.09   3.42  26.06  16.53  11.99
# 24847  Visakhapatnam  2020-06-29   22.91  65.73   3.45  29.53  18.33  10.71
# 24848  Visakhapatnam  2020-06-30   16.64  49.97   4.05  29.26  18.80  10.03
# 24849  Visakhapatnam  2020-07-01   15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.dropna(inplace=True)

# %%
pollutant_features = ['PM2.5' , 'PM10', 'NO', 'NO2', 'NH3', 'CO', 'SO2', 'O3' , 'Benzene' , 'Toluene' ]
target_column = 'AQI'

# %%
print(df.columns.tolist())
# Out:
# ['Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'AQI', 'AQI_Bucket', 'City_Aizawl', 'City_Amaravati', 'City_Amritsar', 'City_Bengaluru', 'City_Bhopal', 'City_Brajrajnagar', 'City_Chandigarh', 'City_Chennai', 'City_Coimbatore', 'City_Delhi', 'City_Ernakulam', 'City_Gurugram', 'City_Guwahati', 'City_Hyderabad', 'City_Jaipur', 'City_Jorapokhar', 'City_Kochi', 'City_Kolkata', 'City_Lucknow', 'City_Mumbai', 'City_Patna', 'City_Shillong', 'City_Talcher', 'City_Thiruvananthapuram', 'City_Visakhapatnam']

# %%
if 'City' in df.columns or 'city' in df.columns:
    column_to_encode = 'City' if 'City' in df.columns else 'city'
    df = pd.get_dummies(df, columns=[column_to_encode], drop_first=True)
else:
    print("Error: Neither 'City' nor 'city' column is present.")
    print("Available columns:", df.columns.tolist())
# Out:
# Error: Neither 'City' nor 'city' column is present.
# Available columns: ['Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'AQI', 'AQI_Bucket', 'City_Aizawl', 'City_Amaravati', 'City_Amritsar', 'City_Bengaluru', 'City_Bhopal', 'City_Brajrajnagar', 'City_Chandigarh', 'City_Chennai', 'City_Coimbatore', 'City_Delhi', 'City_Ernakulam', 'City_Gurugram', 'City_Guwahati', 'City_Hyderabad', 'City_Jaipur', 'City_Jorapokhar', 'City_Kochi', 'City_Kolkata', 'City_Lucknow', 'City_Mumbai', 'City_Patna', 'City_Shillong', 'City_Talcher', 'City_Thiruvananthapuram', 'City_Visakhapatnam']

# %%
##df = pd.get_dummies(df , columns=['City'], drop_first=True)

# %%
feature_columns = pollutant_features + [col for col in df.columns if col.startswith("City_")]

# %%
required_columns = pollutant_features + [traget_column]
for col in required_columns:
    if col not in df.columns:
        raise ValueError(f"Column '{col}' not found in dataset")

x = df[feature_columns]
y = df[target_column]
print(f"Feature (x): {x.columns.tolist()[:15]} ... ({len(x.columns)} total)")
print(f"Target (y): {target_column}")
# Out:
# Feature (x): ['PM2.5', 'PM10', 'NO', 'NO2', 'NH3', 'CO', 'SO2', 'O3', 'Benzene', 'Toluene', 'City_Aizawl', 'City_Amaravati', 'City_Amritsar', 'City_Bengaluru', 'City_Bhopal'] ... (35 total)
# Target (y): AQI

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42) 
print("Data split into training and testing sets.")
# Out:
# Data split into training and testing sets.

# %%
model = RandomForestRegressor(n_estimators=100 , random_state = 42)
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model.predict(x_test)
r2_score = model.score(x_test, y_test)
mae = mean_absolute_error(y_test , y_pred)
rmse = np.sqrt(mean_squared_error(y_test , y_pred))

# %%
print(f"Model R^2 Score: { r2_score: .4f}")
print(f"Mean Absolute Error (MAE) : {mae: .2f}")
print(f"Root Mean Squared Error (RMSE): {rmse: .2f}")
# Out:
# Model R^2 Score:  0.9094
# Mean Absolute Error (MAE) :  20.68
# Root Mean Squared Error (RMSE):  40.73

# %%
timestamp = datetime.datetime.now().strftime('%Ym%d_%H%M%S')
model_filename = f"aqi_model_{timestamp}.pkl"
columns_filename = f"aqi_features_{timestamp}.pkl"

# %%
joblib.dump(model, model_filename)
joblib.dump(feature_columns, columns_filename)
print(f"Model saved successfully as '{model_filename}'")
print(f"Feature columns saved as '{columns_filename}'")
# Out:
# Model saved successfully as 'aqi_model_2025m13_134449.pkl'
# Feature columns saved as 'aqi_features_2025m13_134449.pkl'
